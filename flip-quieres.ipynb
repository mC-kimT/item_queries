# %%
len 10

# %%
#Creative fashion Style
scrape_flipkart = [{
    'url':'https://www.flipkart.com/search?q=coats%20for%20woman&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off',
    'main_container': ['div', "_1xHGtK _373qXS"],

    'fetch_data_item': [   
        ['Name', 'a', "IRpwTa"],
        ['Link', 'a', '_2UzuFa'],
        ['Image', 'img', '_2r_T1I'],
        ['Price', 'div', '_30jeq3'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Flipkart",
    'item_len': Len, 
    'Category': 'Boots',
    'Gender': 'Woman'
},
{
    'url':'https://www.flipkart.com/search?q=jacket%20for%20man&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off',
    'main_container': ['div', "_1xHGtK _373qXS"],

    'fetch_data_item': [   
        ['Name', 'a', "IRpwTa"],
        ['Link', 'a', '_2UzuFa'],
        ['Image', 'img', '_2r_T1I'],
        ['Price', 'div', '_30jeq3'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Flipkart",
    'item_len': Len, 
    'Category': 'Jacket',
    'Gender': 'Woman'
},
    {
    'url':'https://www.flipkart.com/search?q=polo%20shirt%20for%20woman&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off',
    'main_container': ['div', "_1xHGtK _373qXS"],

    'fetch_data_item': [   
        ['Name', 'a', "IRpwTa"],
        ['Link', 'a', '_2UzuFa'],
        ['Image', 'img', '_2r_T1I'],
        ['Price', 'div', '_30jeq3'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Flipkart",
    'item_len': Len, 
    'Category': 'Polo Shirt',
    'Gender': 'Woman'
},
    {
    'url':'https://www.flipkart.com/search?q=vest%20for%20woman&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off',
    'main_container': ['div', "_1xHGtK _373qXS"],

    'fetch_data_item': [   
        ['Name', 'a', "IRpwTa"],
        ['Link', 'a', '_2UzuFa'],
        ['Image', 'img', '_2r_T1I'],
        ['Price', 'div', '_30jeq3'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Flipkart",
    'item_len': Len, 
    'Category': 'Vest',
    'Gender': 'Woman'
},
    {
    'url':'https://www.flipkart.com/search?q=coats%20for%20woman&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off',
    'main_container': ['div', "_1xHGtK _373qXS"],

    'fetch_data_item': [   
        ['Name', 'a', "IRpwTa"],
        ['Link', 'a', '_2UzuFa'],
        ['Image', 'img', '_2r_T1I'],
        ['Price', 'div', '_30jeq3'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Flipkart",
    'item_len': Len, 
    'Category': 'Coats',
    'Gender': 'Woman'
},
      {
    'url':'https://www.flipkart.com/search?q=pants%20for%20women&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off',
    'main_container': ['div', "_1xHGtK _373qXS"],

    'fetch_data_item': [   
        ['Name', 'a', "IRpwTa"],
        ['Link', 'a', '_2UzuFa'],
        ['Image', 'img', '_2r_T1I'],
        ['Price', 'div', '_30jeq3'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Flipkart",
    'item_len': Len, 
    'Category': 'Pants',
    'Gender': 'Woman'
},
    {
    'url':'https://www.flipkart.com/search?q=boots%20for%20men&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off',
    'main_container': ['div', "_1xHGtK _373qXS"],

    'fetch_data_item': [   
        ['Name', 'a', "IRpwTa"],
        ['Link', 'a', '_2UzuFa'],
        ['Image', 'img', '_2r_T1I'],
        ['Price', 'div', '_30jeq3'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Flipkart",
    'item_len': Len, 
    'Category': 'Boots',
    'Gender': 'Men'
},
{
    'url':'https://www.flipkart.com/search?q=jackets%20for%20men&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off',
    'main_container': ['div', "_1xHGtK _373qXS"],

    'fetch_data_item': [   
        ['Name', 'a', "IRpwTa"],
        ['Link', 'a', '_2UzuFa'],
        ['Image', 'img', '_2r_T1I'],
        ['Price', 'div', '_30jeq3'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Flipkart",
    'item_len': Len, 
    'Category': 'Jacket',
    'Gender': 'Men'
},
    {
    'url':'https://www.flipkart.com/search?q=polo%20shirt%20for%20men&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off',
    'main_container': ['div', "_1xHGtK _373qXS"],

    'fetch_data_item': [   
        ['Name', 'a', "IRpwTa"],
        ['Link', 'a', '_2UzuFa'],
        ['Image', 'img', '_2r_T1I'],
        ['Price', 'div', '_30jeq3'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Flipkart",
    'item_len': Len, 
    'Category': 'Polo Shirt',
    'Gender': 'Men'
},
    {
    'url':'https://www.flipkart.com/search?q=vest%20for%20men&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off',
    'main_container': ['div', "_1xHGtK _373qXS"],

    'fetch_data_item': [   
        ['Name', 'a', "IRpwTa"],
        ['Link', 'a', '_2UzuFa'],
        ['Image', 'img', '_2r_T1I'],
        ['Price', 'div', '_30jeq3'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Flipkart",
    'item_len': Len, 
    'Category': 'Vest',
    'Gender': 'Men'
},
    {
    'url':'https://www.flipkart.com/search?q=coats%20for%20men&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off',
    'main_container': ['div', "_1xHGtK _373qXS"],

    'fetch_data_item': [   
        ['Name', 'a', "IRpwTa"],
        ['Link', 'a', '_2UzuFa'],
        ['Image', 'img', '_2r_T1I'],
        ['Price', 'div', '_30jeq3'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Flipkart",
    'item_len': Len, 
    'Category': 'Coats',
    'Gender': 'Men'
},
      {
    'url':'https://www.flipkart.com/search?q=pants%20for%20men&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off',
    'main_container': ['div', "_1xHGtK _373qXS"],

    'fetch_data_item': [   
        ['Name', 'a', "IRpwTa"],
        ['Link', 'a', '_2UzuFa'],
        ['Image', 'img', '_2r_T1I'],
        ['Price', 'div', '_30jeq3'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Flipkart",
    'item_len': Len, 
    'Category': 'Pants',
    'Gender': 'Men'
},
]

# %%
#Modern fashion style
scrape_flipkart = [{
    'url':'https://www.flipkart.com/search?q=modern%20cloth%20for%20woman&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off',
    'main_container': ['div', "_1xHGtK _373qXS"],

    'fetch_data_item': [   
        ['Name', 'a', "IRpwTa"],
        ['Link', 'a', '_2UzuFa'],
        ['Image', 'img', '_2r_T1I'],
        ['Price', 'div', '_30jeq3'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Flipkart",
    'item_len': Len, 
    'Category': 'Modern Cloths',
    'Gender': 'Woman'
},
{
    'url':'https://www.flipkart.com/search?q=bags%20for%20woman&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off',
    'main_container': ['div', "_1xHGtK _373qXS"],

    'fetch_data_item': [   
        ['Name', 'a', "IRpwTa"],
        ['Link', 'a', '_2UzuFa'],
        ['Image', 'img', '_2r_T1I'],
        ['Price', 'div', '_30jeq3'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Flipkart",
    'item_len': Len, 
    'Category': 'Bags',
    'Gender': 'Woman'
},
    {
    'url':'https://www.flipkart.com/search?q=urban%20for%20woman&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off',
    'main_container': ['div', "_1xHGtK _373qXS"],

    'fetch_data_item': [   
        ['Name', 'a', "IRpwTa"],
        ['Link', 'a', '_2UzuFa'],
        ['Image', 'img', '_2r_T1I'],
        ['Price', 'div', '_30jeq3'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Flipkart",
    'item_len': Len, 
    'Category': 'Casual t-shirt',
    'Gender': 'Woman'
},
    {
    'url':'https://www.flipkart.com/search?q=printed+t+shirt+for+women&sid=clo%2Cash%2Cank%2Cloi&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_17_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_17_na_na_na&as-pos=1&as-type=RECENT&suggestionId=printed+t+shirt+for+women%7CWomen%27s+T-shirts&requestId=4b74cf32-2f15-4fa1-b000-d9a0771703b3&as-searchtext=printed%20%20for%20woman',
    'main_container': ['div', "_1xHGtK _373qXS"],

    'fetch_data_item': [   
        ['Name', 'a', "IRpwTa"],
        ['Link', 'a', '_2UzuFa'],
        ['Image', 'img', '_2r_T1I'],
        ['Price', 'div', '_30jeq3'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Flipkart",
    'item_len': Len, 
    'Category': 'Printed t-shirt',
    'Gender': 'Woman'
},
    {
    'url':'https://www.flipkart.com/search?q=summer%20for%20women&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off',
    'main_container': ['div', "_1xHGtK _373qXS"],

    'fetch_data_item': [   
        ['Name', 'a', "IRpwTa"],
        ['Link', 'a', '_2UzuFa'],
        ['Image', 'img', '_2r_T1I'],
        ['Price', 'div', '_30jeq3'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Flipkart",
    'item_len': Len, 
    'Category': 'Summer Cloth',
    'Gender': 'Woman'
},
     {
    'url':'https://www.flipkart.com/clothing-and-accessories/~cs-slqko43dfo/pr?sid=clo&collection-tab-name=Swim%20and%20Beachwear&otracker=nmenu_sub_Women_0_Swim%20%26%20Beachwear&otracker=nmenu_sub_Women_0_Swim%20%26%20Beachwear',
    'main_container': ['div', "_1xHGtK _373qXS"],

    'fetch_data_item': [   
        ['Name', 'a', "IRpwTa"],
        ['Link', 'a', '_2UzuFa'],
        ['Image', 'img', '_2r_T1I'],
        ['Price', 'div', '_30jeq3'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Flipkart",
    'item_len': Len, 
    'Category': 'Swimwear',
    'Gender': 'Woman'
},
     {
    'url':'https://www.flipkart.com/clothing-and-accessories/sleepwear/night-dresses-and-nighties/women-night-dresses-and-nighties/pr?sid=clo,1hc,kc4,nmu&otracker=categorytree&otracker=nmenu_sub_Women_0_Night%20Dresses%20%26%20Nighties&otracker=nmenu_sub_Women_0_Night%20Dresses%20%26%20Nighties',
    'main_container': ['div', "_1xHGtK _373qXS"],

    'fetch_data_item': [   
        ['Name', 'a', "IRpwTa"],
        ['Link', 'a', '_2UzuFa'],
        ['Image', 'img', '_2r_T1I'],
        ['Price', 'div', '_30jeq3'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Flipkart",
    'item_len': Len, 
    'Category': 'Night dress',
    'Gender': 'Woman'
},
    {
    'url':'https://www.flipkart.com/search?q=modern+shirt+for+men&sid=clo%2Cash%2Caxc%2Cmmk%2Ckp7&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_14_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_14_na_na_na&as-pos=1&as-type=RECENT&suggestionId=modern+shirt+for+men%7CCasual+Shirts&requestId=7667ccfe-50be-4a9c-b4a8-171d765ec411&as-searchtext=modern%20%20for%20men',
    'main_container': ['div', "_1xHGtK _373qXS"],

    'fetch_data_item': [   
        ['Name', 'a', "IRpwTa"],
        ['Link', 'a', '_2UzuFa'],
        ['Image', 'img', '_2r_T1I'],
        ['Price', 'div', '_30jeq3'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Flipkart",
    'item_len': Len, 
    'Category': 'Modern Cloths',
    'Gender': 'Men'
},
{
    'url':'https://www.flipkart.com/search?q=bags%20for%20men&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off',
    'main_container': ['div', "_1xHGtK _373qXS"],

    'fetch_data_item': [   
        ['Name', 'a', "IRpwTa"],
        ['Link', 'a', '_2UzuFa'],
        ['Image', 'img', '_2r_T1I'],
        ['Price', 'div', '_30jeq3'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Flipkart",
    'item_len': Len, 
    'Category': 'Bags',
    'Gender': 'Men'
},
    {
    'url':'https://www.flipkart.com/search?q=casual%20t-shirt%20for%20men&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off',
    'main_container': ['div', "_1xHGtK _373qXS"],

    'fetch_data_item': [   
        ['Name', 'a', "IRpwTa"],
        ['Link', 'a', '_2UzuFa'],
        ['Image', 'img', '_2r_T1I'],
        ['Price', 'div', '_30jeq3'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Flipkart",
    'item_len': Len, 
    'Category': 'Casual t-shirt',
    'Gender': 'Men'
},
    {
    'url':'https://www.flipkart.com/search?q=printed%20t-shirt%20for%20men&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off',
    'main_container': ['div', "_1xHGtK _373qXS"],

    'fetch_data_item': [   
        ['Name', 'a', "IRpwTa"],
        ['Link', 'a', '_2UzuFa'],
        ['Image', 'img', '_2r_T1I'],
        ['Price', 'div', '_30jeq3'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Flipkart",
    'item_len': Len, 
    'Category': 'Printed t-shirt',
    'Gender': 'Men'
},
    {
    'url':'https://www.flipkart.com/search?q=summer+t+shirt+for+men&sid=clo%2Cash%2Cank%2Cedy&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_2_20_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_2_20_na_na_na&as-pos=2&as-type=RECENT&suggestionId=summer+t+shirt+for+men%7CMen%27s+T-shirts&requestId=521ed824-227e-43b9-8627-7917fbb41752&as-searchtext=summer%20shirt%20for%20men',
    'main_container': ['div', "_1xHGtK _373qXS"],

    'fetch_data_item': [   
        ['Name', 'a', "IRpwTa"],
        ['Link', 'a', '_2UzuFa'],
        ['Image', 'img', '_2r_T1I'],
        ['Price', 'div', '_30jeq3'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Flipkart",
    'item_len': Len, 
    'Category': 'Summer cloths',
    'Gender': 'Men'
},
     {
    'url':'https://www.flipkart.com/search?q=swimwear%20for%20men&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off',
    'main_container': ['div', "_1xHGtK _373qXS"],

    'fetch_data_item': [   
        ['Name', 'a', "IRpwTa"],
        ['Link', 'a', '_2UzuFa'],
        ['Image', 'img', '_2r_T1I'],
        ['Price', 'div', '_30jeq3'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Flipkart",
    'item_len': Len, 
    'Category': 'Swimwear',
    'Gender': 'Men'
},
]

# %%
#Stylish fashion style
scrape_flipkart = [{
    'url':'https://www.flipkart.com/search?q=dress%20for%20women&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off',
    'main_container': ['div', "_1xHGtK _373qXS"],

    'fetch_data_item': [   
        ['Name', 'a', "IRpwTa"],
        ['Link', 'a', '_2UzuFa'],
        ['Image', 'img', '_2r_T1I'],
        ['Price', 'div', '_30jeq3'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Flipkart",
    'item_len': Len, 
    'Category': 'Dress',
    'Gender': 'Woman'
},{
    'url':'https://www.flipkart.com/search?q=jeans%20for%20women&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off',
    'main_container': ['div', "_1xHGtK _373qXS"],

    'fetch_data_item': [   
        ['Name', 'a', "IRpwTa"],
        ['Link', 'a', '_2UzuFa'],
        ['Image', 'img', '_2r_T1I'],
        ['Price', 'div', '_30jeq3'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Flipkart",
    'item_len': Len, 
    'Category': 'Jeans',
    'Gender': 'Woman'
},
    {
    'url':'https://www.flipkart.com/search?q=shirts%20for%20women&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off',
    'main_container': ['div', "_1xHGtK _373qXS"],

    'fetch_data_item': [   
        ['Name', 'a', "IRpwTa"],
        ['Link', 'a', '_2UzuFa'],
        ['Image', 'img', '_2r_T1I'],
        ['Price', 'div', '_30jeq3'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Flipkart",
    'item_len': Len, 
    'Category': 'Shirts',
    'Gender': 'Woman'
},
    {
    'url':'https://www.flipkart.com/clothing-and-accessories/bottomwear/shorts/womens-shorts/pr?sid=clo,vua,e8g,hbd&q=short+for+women&otracker=categorytree',
    'main_container': ['div', "_1xHGtK _373qXS"],

    'fetch_data_item': [   
        ['Name', 'a', "IRpwTa"],
        ['Link', 'a', '_2UzuFa'],
        ['Image', 'img', '_2r_T1I'],
        ['Price', 'div', '_30jeq3'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Flipkart",
    'item_len': Len, 
    'Category': 'Shorts',
    'Gender': 'Woman'
},
    {
    'url':'https://www.flipkart.com/clothing-and-accessories/dresses-and-gown/dress/women-dress/pr?sid=clo%2Codx%2Cmaj%2Cjhy&otracker=categorytree&p%5B%5D=facets.occasion%255B%255D%3DParty&otracker=nmenu_sub_Women_0_Party%20Dresses&otracker=nmenu_sub_Women_0_Party%20Dresses',
    'main_container': ['div', "_1xHGtK _373qXS"],

    'fetch_data_item': [   
        ['Name', 'a', "IRpwTa"],
        ['Link', 'a', '_2UzuFa'],
        ['Image', 'img', '_2r_T1I'],
        ['Price', 'div', '_30jeq3'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Flipkart",
    'item_len': Len, 
    'Category': 'Party dress',
    'Gender': 'Woman'
},
    {
    'url':'https://www.flipkart.com/search?q=winter+coat+for+women&sid=clo%2Cupk%2C6zw%2Chkw&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_16_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_16_na_na_na&as-pos=1&as-type=RECENT&suggestionId=winter+coat+for+women%7CWomen%27s+Coats&requestId=4bb1b50d-cb90-446b-bfa4-9cb8667ae65c&as-searchtext=winter%20for%20women',
    'main_container': ['div', "_1xHGtK _373qXS"],

    'fetch_data_item': [   
        ['Name', 'a', "IRpwTa"],
        ['Link', 'a', '_2UzuFa'],
        ['Image', 'img', '_2r_T1I'],
        ['Price', 'div', '_30jeq3'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Flipkart",
    'item_len': Len, 
    'Category': 'Winter Coats',
    'Gender': 'Woman'
},
    {
    'url':'https://www.flipkart.com/clothing-and-accessories/bottomwear/~cs-g50m8job1g/pr?sid=clo%2Cvua&collection-tab-name=Trousers%20and%20Capris&otracker=nmenu_sub_Women_0_Trousers%20%26%20Capris&otracker=nmenu_sub_Women_0_Trousers%20%26%20Capris',
    'main_container': ['div', "_1xHGtK _373qXS"],

    'fetch_data_item': [   
        ['Name', 'a', "IRpwTa"],
        ['Link', 'a', '_2UzuFa'],
        ['Image', 'img', '_2r_T1I'],
        ['Price', 'div', '_30jeq3'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Flipkart",
    'item_len': Len, 
    'Category': 'Trousers',
    'Gender': 'Woman'
},
     {
    'url':'https://www.flipkart.com/clothing-and-accessories/bottomwear/skirts/women-skirts/pr?sid=clo,vua,iku,w5t&otracker=categorytree&otracker=nmenu_sub_Women_0_Skirts&otracker=nmenu_sub_Women_0_Skirts',
    'main_container': ['div', "_1xHGtK _373qXS"],

    'fetch_data_item': [   
        ['Name', 'a', "IRpwTa"],
        ['Link', 'a', '_2UzuFa'],
        ['Image', 'img', '_2r_T1I'],
        ['Price', 'div', '_30jeq3'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Flipkart",
    'item_len': Len, 
    'Category': 'Skirts',
    'Gender': 'Woman'
},
   {
    'url':'https://www.flipkart.com/search?q=jeans%20for%20men&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off',
    'main_container': ['div', "_1xHGtK _373qXS"],

    'fetch_data_item': [   
        ['Name', 'a', "IRpwTa"],
        ['Link', 'a', '_2UzuFa'],
        ['Image', 'img', '_2r_T1I'],
        ['Price', 'div', '_30jeq3'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Flipkart",
    'item_len': Len, 
    'Category': 'Jeans',
    'Gender': 'Men'
},
    {
    'url':'https://www.flipkart.com/search?q=shirt%20for%20men&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off',
    'main_container': ['div', "_1xHGtK _373qXS"],

    'fetch_data_item': [   
        ['Name', 'a', "IRpwTa"],
        ['Link', 'a', '_2UzuFa'],
        ['Image', 'img', '_2r_T1I'],
        ['Price', 'div', '_30jeq3'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Flipkart",
    'item_len': Len, 
    'Category': 'Shirts',
    'Gender': 'Men'
},
    {
    'url':'https://www.flipkart.com/search?q=short%20for%20men&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off',
    'main_container': ['div', "_1xHGtK _373qXS"],

    'fetch_data_item': [   
        ['Name', 'a', "IRpwTa"],
        ['Link', 'a', '_2UzuFa'],
        ['Image', 'img', '_2r_T1I'],
        ['Price', 'div', '_30jeq3'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Flipkart",
    'item_len': Len, 
    'Category': 'Shorts',
    'Gender': 'Men'
},
    {
    'url':'https://www.flipkart.com/search?q=party+wear+shirts+for+men&sid=clo%2Cash%2Caxc%2Cmmk%2Ckp7&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_13_na_na_ps&otracker1=AS_QueryStore_OrganicAutoSuggest_1_13_na_na_ps&as-pos=1&as-type=RECENT&suggestionId=party+wear+shirts+for+men%7CCasual+Shirts&requestId=90e56bc3-e724-481c-aac6-f6f3d83379f4&as-searchtext=party%20%20for%20men',
    'main_container': ['div', "_1xHGtK _373qXS"],

    'fetch_data_item': [   
        ['Name', 'a', "IRpwTa"],
        ['Link', 'a', '_2UzuFa'],
        ['Image', 'img', '_2r_T1I'],
        ['Price', 'div', '_30jeq3'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Flipkart",
    'item_len': Len, 
    'Category': 'Party wear',
    'Gender': 'Men'
},
    {
    'url':'https://www.flipkart.com/search?q=winter%20coat%20for%20men%20&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off',
    'main_container': ['div', "_1xHGtK _373qXS"],

    'fetch_data_item': [   
        ['Name', 'a', "IRpwTa"],
        ['Link', 'a', '_2UzuFa'],
        ['Image', 'img', '_2r_T1I'],
        ['Price', 'div', '_30jeq3'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Flipkart",
    'item_len': Len, 
    'Category': 'Winter Coats',
    'Gender': 'Men'
},
    {
    'url':'https://www.flipkart.com/search?q=trouser%20for%20men%20&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off',
    'main_container': ['div', "_1xHGtK _373qXS"],

    'fetch_data_item': [   
        ['Name', 'a', "IRpwTa"],
        ['Link', 'a', '_2UzuFa'],
        ['Image', 'img', '_2r_T1I'],
        ['Price', 'div', '_30jeq3'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Flipkart",
    'item_len': Len, 
    'Category': 'Trousers',
    'Gender': 'Men'
},
]

# %%
#Sport fashion style
scrape_flipkart = [{
    'url':'https://www.flipkart.com/search?q=sports%20bra%20for%20women&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off',
    'main_container': ['div', "_1xHGtK _373qXS"],

    'fetch_data_item': [   
        ['Name', 'a', "IRpwTa"],
        ['Link', 'a', '_2UzuFa'],
        ['Image', 'img', '_2r_T1I'],
        ['Price', 'div', '_30jeq3'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Flipkart",
    'item_len': Len, 
    'Category': 'Sports bra',
    'Gender': 'Woman'
},{
    'url':'https://www.flipkart.com/search?q=sports%20shoes%20for%20women&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off',
    'main_container': ['div', "_1xHGtK _373qXS"],

    'fetch_data_item': [   
        ['Name', 'a', "IRpwTa"],
        ['Link', 'a', '_2UzuFa'],
        ['Image', 'img', '_2r_T1I'],
        ['Price', 'div', '_30jeq3'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Flipkart",
    'item_len': Len, 
    'Category': 'Sport shoes',
    'Gender': 'Woman'
},
    {
    'url':'https://www.flipkart.com/search?q=sports%20bags%20for%20women&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off',
    'main_container': ['div', "_1xHGtK _373qXS"],

    'fetch_data_item': [   
        ['Name', 'a', "IRpwTa"],
        ['Link', 'a', '_2UzuFa'],
        ['Image', 'img', '_2r_T1I'],
        ['Price', 'div', '_30jeq3'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Flipkart",
    'item_len': Len, 
    'Category': 'Sports bag',
    'Gender': 'Woman'
},
    {
    'url':'https://www.flipkart.com/search?q=activewear%20for%20women&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off',
    'main_container': ['div', "_1xHGtK _373qXS"],

    'fetch_data_item': [   
        ['Name', 'a', "IRpwTa"],
        ['Link', 'a', '_2UzuFa'],
        ['Image', 'img', '_2r_T1I'],
        ['Price', 'div', '_30jeq3'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Flipkart",
    'item_len': Len, 
    'Category': 'activewear',
    'Gender': 'Woman'
},
    {
    'url':'https://www.flipkart.com/search?q=trunks%20for%20women&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off',
    'main_container': ['div', "_1xHGtK _373qXS"],

    'fetch_data_item': [   
        ['Name', 'a', "IRpwTa"],
        ['Link', 'a', '_2UzuFa'],
        ['Image', 'img', '_2r_T1I'],
        ['Price', 'div', '_30jeq3'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Flipkart",
    'item_len': Len, 
    'Category': 'Trunks',
    'Gender': 'Woman'
},
    {
    'url':'https://www.flipkart.com/search?q=sports%20headband%20for%20women&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off',
    'main_container': ['div', "_1xHGtK _373qXS"],

    'fetch_data_item': [   
        ['Name', 'a', "IRpwTa"],
        ['Link', 'a', '_2UzuFa'],
        ['Image', 'img', '_2r_T1I'],
        ['Price', 'div', '_30jeq3'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Flipkart",
    'item_len': Len, 
    'Category': 'Sport headband',
    'Gender': 'Woman'
},
     {
    'url':'https://www.flipkart.com/search?q=jugging%20pants%20for%20woman&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off',
    'main_container': ['div', "_1xHGtK _373qXS"],

    'fetch_data_item': [   
        ['Name', 'a', "IRpwTa"],
        ['Link', 'a', '_2UzuFa'],
        ['Image', 'img', '_2r_T1I'],
        ['Price', 'div', '_30jeq3'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Flipkart",
    'item_len': Len, 
    'Category': 'Jugging Pants',
    'Gender': 'Woman'
},
   {
    'url':'https://www.flipkart.com/search?q=sport%20shoes%20for%20men&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off',
    'main_container': ['div', "_1xHGtK _373qXS"],

    'fetch_data_item': [   
        ['Name', 'a', "IRpwTa"],
        ['Link', 'a', '_2UzuFa'],
        ['Image', 'img', '_2r_T1I'],
        ['Price', 'div', '_30jeq3'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Flipkart",
    'item_len': Len, 
    'Category': 'Sport shoes',
    'Gender': 'Men'
},
    {
    'url':'https://www.flipkart.com/search?q=sport%20bag%20for%20men&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off',
    'main_container': ['div', "_1xHGtK _373qXS"],

    'fetch_data_item': [   
        ['Name', 'a', "IRpwTa"],
        ['Link', 'a', '_2UzuFa'],
        ['Image', 'img', '_2r_T1I'],
        ['Price', 'div', '_30jeq3'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Flipkart",
    'item_len': Len, 
    'Category': 'Sports bag',
    'Gender': 'Men'
},
    {
    'url':'https://www.flipkart.com/search?q=activewear%20for%20men&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off',
    'main_container': ['div', "_1xHGtK _373qXS"],

    'fetch_data_item': [   
        ['Name', 'a', "IRpwTa"],
        ['Link', 'a', '_2UzuFa'],
        ['Image', 'img', '_2r_T1I'],
        ['Price', 'div', '_30jeq3'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Flipkart",
    'item_len': Len, 
    'Category': 'activewear',
    'Gender': 'Men'
},
    {
    'url':'https://www.flipkart.com/search?q=trunks%20for%20men&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off',
    'main_container': ['div', "_1xHGtK _373qXS"],

    'fetch_data_item': [   
        ['Name', 'a', "IRpwTa"],
        ['Link', 'a', '_2UzuFa'],
        ['Image', 'img', '_2r_T1I'],
        ['Price', 'div', '_30jeq3'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Flipkart",
    'item_len': Len, 
    'Category': 'Trunks',
    'Gender': 'Men'
},
    {
    'url':'https://www.flipkart.com/search?q=sport%20headband%20for%20men&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off',
    'main_container': ['div', "_1xHGtK _373qXS"],

    'fetch_data_item': [   
        ['Name', 'a', "IRpwTa"],
        ['Link', 'a', '_2UzuFa'],
        ['Image', 'img', '_2r_T1I'],
        ['Price', 'div', '_30jeq3'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Flipkart",
    'item_len': Len, 
    'Category': 'Sport headband',
    'Gender': 'Men'
},
    {
    'url':'https://www.flipkart.com/search?q=jugging%20pants%20for%20men&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off',
    'main_container': ['div', "_1xHGtK _373qXS"],

    'fetch_data_item': [   
        ['Name', 'a', "IRpwTa"],
        ['Link', 'a', '_2UzuFa'],
        ['Image', 'img', '_2r_T1I'],
        ['Price', 'div', '_30jeq3'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Flipkart",
    'item_len': Len, 
    'Category': 'Jugging Pants',
    'Gender': 'Men'
},
]
