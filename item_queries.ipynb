# %%
Len = 10

# %%
# flipkart
scrape_flipkart = [{
    'url':'https://www.flipkart.com/search?q=jacket%20for%20man&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off',
    'main_container': ['div', "_1xHGtK _373qXS"],

    'fetch_data_item': [   
        ['Name', 'a', "IRpwTa"],
        ['Link', 'a', '_2UzuFa'],
        ['Image', 'img', '_2r_T1I'],
        ['Price', 'div', '_30jeq3']
    ],
    
    'Store': "Flipkart",
    'item_len': Len, 
    'Category': 'Jacket',
    'Gender': 'Men'
},{
    'url':'https://www.flipkart.com/search?q=jeans%20for%20man&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off',
    'main_container': ['div', "_1xHGtK _373qXS"],

    'fetch_data_item': [   
        ['Name', 'a', "IRpwTa"],
        ['Link', 'a', '_2UzuFa'],
        ['Image', 'img', '_2r_T1I'],
        ['Price', 'div', '_30jeq3']
    ],
    
    'Store': "Flipkart",
    'item_len': Len, 
    'Category': 'Jeans',
    'Gender': 'Men'
},{
    'url':'https://www.flipkart.com/search?q=pants%20for%20man&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off',
    'main_container': ['div', "_1xHGtK _373qXS"],

    'fetch_data_item': [   
        ['Name', 'a', "IRpwTa"],
        ['Link', 'a', '_2UzuFa'],
        ['Image', 'img', '_2r_T1I'],
        ['Price', 'div', '_30jeq3']
    ],
    
    'Store': "Flipkart",
    'item_len': Len, 
    'Category': 'Pants',
    'Gender': 'Men'
},{
    'url':'https://www.flipkart.com/search?q=shorts%20for%20man&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off',
    'main_container': ['div', "_1xHGtK _373qXS"],

    'fetch_data_item': [   
        ['Name', 'a', "IRpwTa"],
        ['Link', 'a', '_2UzuFa'],
        ['Image', 'img', '_2r_T1I'],
        ['Price', 'div', '_30jeq3']
    ],
    
    'Store': "Flipkart",
    'item_len': Len, 
    'Category': 'Shorts',
    'Gender': 'Men'
},{
    'url':'https://www.flipkart.com/search?q=shirts%20for%20man&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off',
    'main_container': ['div', "_1xHGtK _373qXS"],

    'fetch_data_item': [   
        ['Name', 'a', "IRpwTa"],
        ['Link', 'a', '_2UzuFa'],
        ['Image', 'img', '_2r_T1I'],
        ['Price', 'div', '_30jeq3']
    ],
    
    'Store': "Flipkart",
    'item_len': Len, 
    'Category': 'Shirts',
    'Gender': 'Men'
},{
    'url':'https://www.flipkart.com/search?q=beilt%20for%20man&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off',
    'main_container': ['div', "_1xHGtK _373qXS"],

    'fetch_data_item': [   
        ['Name', 'a', "IRpwTa"],
        ['Link', 'a', '_2UzuFa'],
        ['Image', 'img', '_2r_T1I'],
        ['Price', 'div', '_30jeq3']
    ],
    
    'Store': "Flipkart",
    'item_len': Len, 
    'Category': 'Belt',
    'Gender': 'Men'
},{
    'url':'https://www.flipkart.com/search?q=dress%20for%20women&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off',
    'main_container': ['div', "_1xHGtK _373qXS"],

    'fetch_data_item': [   
        ['Name', 'a', "IRpwTa"],
        ['Link', 'a', '_2UzuFa'],
        ['Image', 'img', '_2r_T1I'],
        ['Price', 'div', '_30jeq3']
    ],
    
    'Store': "Flipkart",
    'item_len': Len, 
    'Category': 'Dress',
    'Gender': 'Woman'
},{
    'url':'https://www.flipkart.com/search?q=jeans%20for%20women&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off',
    'main_container': ['div', "_1xHGtK _373qXS"],

    'fetch_data_item': [   
        ['Name', 'a', "IRpwTa"],
        ['Link', 'a', '_2UzuFa'],
        ['Image', 'img', '_2r_T1I'],
        ['Price', 'div', '_30jeq3']
    ],
    
    'Store': "Flipkart",
    'item_len': Len, 
    'Category': 'Jeans',
    'Gender': 'Woman'
},{
    'url':'https://www.flipkart.com/search?q=pants%20for%20women&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off',
    'main_container': ['div', "_1xHGtK _373qXS"],

    'fetch_data_item': [   
        ['Name', 'a', "IRpwTa"],
        ['Link', 'a', '_2UzuFa'],
        ['Image', 'img', '_2r_T1I'],
        ['Price', 'div', '_30jeq3']
    ],
    
    'Store': "Flipkart",
    'item_len': Len, 
    'Category': 'Pants',
    'Gender': 'Woman'
},{
    'url':'https://www.flipkart.com/search?q=short%20for%20women&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off',
    'main_container': ['div', "_1xHGtK _373qXS"],

    'fetch_data_item': [   
        ['Name', 'a', "IRpwTa"],
        ['Link', 'a', '_2UzuFa'],
        ['Image', 'img', '_2r_T1I'],
        ['Price', 'div', '_30jeq3']
    ],
    
    'Store': "Flipkart",
    'item_len': Len, 
    'Category': 'Short',
    'Gender': 'Woman'
},{
    'url':'https://www.flipkart.com/search?q=skirt%20for%20women&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off',
    'main_container': ['div', "_1xHGtK _373qXS"],

    'fetch_data_item': [   
        ['Name', 'a', "IRpwTa"],
        ['Link', 'a', '_2UzuFa'],
        ['Image', 'img', '_2r_T1I'],
        ['Price', 'div', '_30jeq3']
    ],
    
    'Store': "Flipkart",
    'item_len': Len, 
    'Category': 'Skirt',
    'Gender': 'Woman'
},{
    'url':'https://www.flipkart.com/search?q=shirts%20for%20women&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off',
    'main_container': ['div', "_1xHGtK _373qXS"],

    'fetch_data_item': [   
        ['Name', 'a', "IRpwTa"],
        ['Link', 'a', '_2UzuFa'],
        ['Image', 'img', '_2r_T1I'],
        ['Price', 'div', '_30jeq3']
    ],
    
    'Store': "Flipkart",
    'item_len': Len, 
    'Category': 'Shirts',
    'Gender': 'Woman'
},{
    'url':'https://www.flipkart.com/search?q=belt%20for%20woman&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off',
    'main_container': ['div', "_1xHGtK _373qXS"],

    'fetch_data_item': [   
        ['Name', 'a', "IRpwTa"],
        ['Link', 'a', '_2UzuFa'],
        ['Image', 'img', '_2r_T1I'],
        ['Price', 'div', '_30jeq3']
    ],
    
    'Store': "Flipkart",
    'item_len': Len, 
    'Category': 'Belt',
    'Gender': 'Woman'
},
]

# %%
# for param in scrape_flipkart:
#     items = param['fetch_data_item']
#     len_img = len( items[2])
#     if len_img == 3:
#         print(3)
#     else: print(2)

# %%
scrape_amazon = [{
    'url':'https://www.amazon.com/s?k=jacket+for+men&sprefix=jacket+%2Caps%2C393&ref=nb_sb_ss_ts-doa-p_1_7',
    'main_container': ['div', "a-section a-spacing-base"],

    'fetch_data_item': [   
        ['Name', 'span', "a-size-base-plus a-color-base a-text-normal"],
        ['Link', 'a', 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'],
        ['Image', 'img', 's-image'],
        ['Price', 'span', 'a-offscreen']
    ],
    
    'Store': "Amazon",
    'item_len': Len, 
    'Category': 'Jacket',
    'Gender' : 'Men'
},{
    'url':'https://www.amazon.com/s?k=jeans+for+man&crid=3QID7KJ7BE9IP&sprefix=jeans+for+man%2Caps%2C372&ref=nb_sb_noss_1',
    'main_container': ['div', "a-section a-spacing-base"],

    'fetch_data_item': [   
        ['Name', 'span', "a-size-base-plus a-color-base a-text-normal"],
        ['Link', 'a', 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'],
        ['Image', 'img', 's-image'],
        ['Price', 'span', 'a-offscreen']
    ],
    
    'Store': "Amazon",
    'item_len': Len, 
    'Category': 'Jeans',
    'Gender' : 'Men'
},{
    'url':'https://www.amazon.com/s?k=pants+for+man&crid=3QB262907AST7&sprefix=pants+for+ma%2Caps%2C342&ref=nb_sb_noss_2',
    'main_container': ['div', "a-section a-spacing-base"],

    'fetch_data_item': [   
        ['Name', 'span', "a-size-base-plus a-color-base a-text-normal"],
        ['Link', 'a', 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'],
        ['Image', 'img', 's-image'],
        ['Price', 'span', 'a-offscreen']
    ],
    
    'Store': "Amazon",
    'item_len': Len, 
    'Category': 'Pants',
    'Gender' : 'Men'
},{
    'url':'https://www.amazon.com/s?k=shorts+for+man&crid=2SK59EPW7SNCL&sprefix=shorts+for+man%2Caps%2C418&ref=nb_sb_noss_1',
    'main_container': ['div', "a-section a-spacing-base"],

    'fetch_data_item': [   
        ['Name', 'span', "a-size-base-plus a-color-base a-text-normal"],
        ['Link', 'a', 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'],
        ['Image', 'img', 's-image'],
        ['Price', 'span', 'a-offscreen']
    ],
    
    'Store': "Amazon",
    'item_len': Len, 
    'Category': 'Shorts',
    'Gender' : 'Men'
},{
    'url':'https://www.amazon.com/s?k=shirts+for+man&crid=1ILF6BAU0OO43&sprefix=shirts+for+man%2Caps%2C668&ref=nb_sb_noss_2',
    'main_container': ['div', "a-section a-spacing-base"],

    'fetch_data_item': [   
        ['Name', 'span', "a-size-base-plus a-color-base a-text-normal"],
        ['Link', 'a', 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'],
        ['Image', 'img', 's-image'],
        ['Price', 'span', 'a-offscreen']
    ],
    
    'Store': "Amazon",
    'item_len': Len, 
    'Category': 'Shirts',
    'Gender' : 'Men'
},{
    'url':'https://www.amazon.com/s?k=belt+for+man&crid=1X13ZQ64Z8M5T&sprefix=belt+for+man%2Caps%2C536&ref=nb_sb_noss_2',
    'main_container': ['div', "a-section a-spacing-base"],

    'fetch_data_item': [   
        ['Name', 'span', "a-size-base-plus a-color-base a-text-normal"],
        ['Link', 'a', 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'],
        ['Image', 'img', 's-image'],
        ['Price', 'span', 'a-offscreen']
    ],
    
    'Store': "Amazon",
    'item_len': Len, 
    'Category': 'Belt',
    'Gender' : 'Men'
},{
    'url':'https://www.amazon.com/s?k=womans+dress&crid=Y66AYH804CYJ&sprefix=womans+dress%2Caps%2C459&ref=nb_sb_noss_1',
    'main_container': ['div', "a-section a-spacing-base"],

    'fetch_data_item': [   
        ['Name', 'span', "a-size-base-plus a-color-base a-text-normal"],
        ['Link', 'a', 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'],
        ['Image', 'img', 's-image'],
        ['Price', 'span', 'a-offscreen']
    ],
    
    'Store': "Amazon",
    'item_len': Len, 
    'Category': 'Dress',
    'Gender' : 'Woman'
},{
    'url':'https://www.amazon.com/s?k=jeans+for+women&sprefix=jeans+for+%2Caps%2C825&ref=nb_sb_ss_ts-doa-p_1_10',
    'main_container': ['div', "a-section a-spacing-base"],

    'fetch_data_item': [   
        ['Name', 'span', "a-size-base-plus a-color-base a-text-normal"],
        ['Link', 'a', 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'],
        ['Image', 'img', 's-image'],
        ['Price', 'span', 'a-offscreen']
    ],
    
    'Store': "Amazon",
    'item_len': Len, 
    'Category': 'Jeans',
    'Gender' : 'Woman'
},{
    'url':'https://www.amazon.com/s?k=pants+for+women&crid=3PZEBVJF5SLB8&sprefix=pants+for+women%2Caps%2C525&ref=nb_sb_noss_1',
    'main_container': ['div', "a-section a-spacing-base"],

    'fetch_data_item': [   
        ['Name', 'span', "a-size-base-plus a-color-base a-text-normal"],
        ['Link', 'a', 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'],
        ['Image', 'img', 's-image'],
        ['Price', 'span', 'a-offscreen']
    ],
    
    'Store': "Amazon",
    'item_len': Len, 
    'Category': 'Pants',
    'Gender' : 'Woman'
},{
    'url':'https://www.amazon.com/s?k=shirts+for+women&crid=28YWPPOIUUI3N&sprefix=shirts+for+women%2Caps%2C444&ref=nb_sb_noss_1',
    'main_container': ['div', "a-section a-spacing-base"],

    'fetch_data_item': [   
        ['Name', 'span', "a-size-base-plus a-color-base a-text-normal"],
        ['Link', 'a', 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'],
        ['Image', 'img', 's-image'],
        ['Price', 'span', 'a-offscreen']
    ],
    
    'Store': "Amazon",
    'item_len': Len, 
    'Category': 'Shirts',
    'Gender' : 'Woman'
},{
    'url':'https://www.amazon.com/s?k=shorts+for+women&crid=T58GQ7XD1C8Y&sprefix=shirts+for+women%2Caps%2C551&ref=nb_sb_noss_1',
    'main_container': ['div', "a-section a-spacing-base"],

    'fetch_data_item': [   
        ['Name', 'span', "a-size-base-plus a-color-base a-text-normal"],
        ['Link', 'a', 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'],
        ['Image', 'img', 's-image'],
        ['Price', 'span', 'a-offscreen']
    ],
    
    'Store': "Amazon",
    'item_len': Len, 
    'Category': 'Shorts',
    'Gender' : 'Woman'
},{
    'url':'https://www.amazon.com/s?k=skirt+for+women&crid=3FK9YY7EK7LFK&sprefix=skirt+for+women%2Caps%2C410&ref=nb_sb_noss_1',
    'main_container': ['div', "a-section a-spacing-base"],

    'fetch_data_item': [   
        ['Name', 'span', "a-size-base-plus a-color-base a-text-normal"],
        ['Link', 'a', 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'],
        ['Image', 'img', 's-image'],
        ['Price', 'span', 'a-offscreen']
    ],
    
    'Store': "Amazon",
    'item_len': Len, 
    'Category': 'Skirt',
    'Gender' : 'Woman'
},{
    'url':'https://www.amazon.com/s?k=belts+for+women&sprefix=belt%2Caps%2C501&ref=nb_sb_ss_ts-doa-p_1_4',
    'main_container': ['div', "a-section a-spacing-base"],

    'fetch_data_item': [   
        ['Name', 'span', "a-size-base-plus a-color-base a-text-normal"],
        ['Link', 'a', 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'],
        ['Image', 'img', 's-image'],
        ['Price', 'span', 'a-offscreen']
    ],
    
    'Store': "Amazon",
    'item_len': Len, 
    'Category': 'Belts',
    'Gender' : 'Woman'
}]

# %%
# format
scrape_eBay = [{
    'url':'https://www.ebay.ph/sch/i.html?_from=R40&_trksid=m570.l1313&_nkw=mens+jacket+&_sacat=0&LH_TitleDesc=0&_odkw=dress&_osacat=0',
    'main_container':['li', 's-item s-item__pl-on-bottom'],
    
    'fetch_data_item':[
        ['Name', 'div', 's-item__title'],
        ['Link', 'a', 's-item__link'],
        ['Image', 'img', 's-item__image-img'],
        ['Price', 'span', 's-item__price']
    ],
    
    'Store': 'eBay',
    'item_len': Len,
    'Category': 'Jacket',
    'Gender' : 'Men'
},{
    'url': 'https://www.ebay.ph/sch/i.html?_from=R40&_trksid=m570.l1313&_nkw=mens+jeans&_sacat=0&LH_TitleDesc=0&_odkw=dress&_osacat=0',
    'main_container':['li', 's-item s-item__pl-on-bottom'],
    
    'fetch_data_item':[
        ['Name', 'div', 's-item__title'],
        ['Link', 'a', 's-item__link'],
        ['Image', 'img', 's-item__image-img'],
        ['Price', 'span', 's-item__price']
    ],
    
    'Store': 'eBay',
    'item_len': Len,
    'Category': 'Jeans',
    'Gender' : 'Men'
},{
    'url': 'https://www.ebay.ph/sch/i.html?_from=R40&_trksid=m570.l1313&_nkw=mens+pants&_sacat=0&LH_TitleDesc=0&_odkw=mens+jeans&_osacat=0&LH_PrefLoc=2',
    'main_container':['li', 's-item s-item__pl-on-bottom'],
    
    'fetch_data_item':[
        ['Name', 'div', 's-item__title'],
        ['Link', 'a', 's-item__link'],
        ['Image', 'img', 's-item__image-img'],
        ['Price', 'span', 's-item__price']
    ],
    
    'Store': 'eBay',
    'item_len': Len,
    'Category': 'Pants',
    'Gender' : 'Men'
},{
    'url': 'https://www.ebay.ph/sch/i.html?_from=R40&_trksid=m570.l1313&_nkw=mens+shorts+&_sacat=0&LH_TitleDesc=0&_odkw=mens+pants&_osacat=0&LH_PrefLoc=2',
    'main_container':['li', 's-item s-item__pl-on-bottom'],
    
    'fetch_data_item':[
        ['Name', 'div', 's-item__title'],
        ['Link', 'a', 's-item__link'],
        ['Image', 'img', 's-item__image-img'],
        ['Price', 'span', 's-item__price']
    ],
    
    'Store': 'eBay',
    'item_len': Len,
    'Category': 'Shorts',
    'Gender' : 'Men'
},{
    'url': 'https://www.ebay.ph/sch/i.html?_from=R40&_trksid=m570.l1313&_nkw=mens+shirts++&_sacat=0',
    'main_container':['li', 's-item s-item__pl-on-bottom'],
    
    'fetch_data_item':[
        ['Name', 'div', 's-item__title'],
        ['Link', 'a', 's-item__link'],
        ['Image', 'img', 's-item__image-img'],
        ['Price', 'span', 's-item__price']
    ],
    
    'Store': 'eBay',
    'item_len': Len,
    'Category': 'Shirts',
    'Gender' : 'Men'
},{
    'url': 'https://www.ebay.ph/sch/i.html?_from=R40&_trksid=m570.l1313&_nkw=mens+belts+&_sacat=0&LH_TitleDesc=0&_odkw=mens+shirts++&_osacat=0',
    'main_container':['li', 's-item s-item__pl-on-bottom'],
    
    'fetch_data_item':[
        ['Name', 'div', 's-item__title'],
        ['Link', 'a', 's-item__link'],
        ['Image', 'img', 's-item__image-img'],
        ['Price', 'span', 's-item__price']
    ],
    
    'Store': 'eBay',
    'item_len': Len,
    'Category': 'Belt',
    'Gender' : 'Men'
},{
    'url': 'https://www.ebay.ph/sch/i.html?_from=R40&_trksid=m570.l1313&_nkw=woman+dress&_sacat=0&LH_TitleDesc=0&_odkw=woman+dress+&_osacat=0&LH_PrefLoc=2',
    'main_container':['li', 's-item s-item__pl-on-bottom'],
    
    'fetch_data_item':[
        ['Name', 'div', 's-item__title'],
        ['Link', 'a', 's-item__link'],
        ['Image', 'img', 's-item__image-img'],
        ['Price', 'span', 's-item__price']
    ],
    
    'Store': 'eBay',
    'item_len': Len,
    'Category': 'Dress',
    'Gender': 'Woman'
},{
    'url': 'https://www.ebay.ph/sch/i.html?_from=R40&_trksid=m570.l1313&_nkw=woman+jeans+&_sacat=0&LH_TitleDesc=0&_odkw=woman+dress&_osacat=0&LH_PrefLoc=2',
    'main_container':['li', 's-item s-item__pl-on-bottom'],
    
    'fetch_data_item':[
        ['Name', 'div', 's-item__title'],
        ['Link', 'a', 's-item__link'],
        ['Image', 'img', 's-item__image-img'],
        ['Price', 'span', 's-item__price']
    ],
    
    'Store': 'eBay',
    'item_len': Len,
    'Category': 'Jeans',
    'Gender': 'Woman'
},{
    'url': 'https://www.ebay.ph/sch/i.html?_from=R40&_trksid=m570.l1313&_nkw=woman+pants+&_sacat=0&LH_TitleDesc=0&_odkw=woman+jeans+&_osacat=0&LH_PrefLoc=2',
    'main_container':['li', 's-item s-item__pl-on-bottom'],
    
    'fetch_data_item':[
        ['Name', 'div', 's-item__title'],
        ['Link', 'a', 's-item__link'],
        ['Image', 'img', 's-item__image-img'],
        ['Price', 'span', 's-item__price']
    ],
    
    'Store': 'eBay',
    'item_len': Len,
    'Category': 'Pants',
    'Gender': 'Woman'
},{
    'url': 'https://www.ebay.ph/sch/i.html?_from=R40&_trksid=m570.l1313&_nkw=woman+shirts+&_sacat=0&LH_TitleDesc=0&_odkw=woman+pants+&_osacat=0&LH_PrefLoc=2',
    'main_container':['li', 's-item s-item__pl-on-bottom'],
    
    'fetch_data_item':[
        ['Name', 'div', 's-item__title'],
        ['Link', 'a', 's-item__link'],
        ['Image', 'img', 's-item__image-img'],
        ['Price', 'span', 's-item__price']
    ],
    
    'Store': 'eBay',
    'item_len': Len,
    'Category': 'Shirts',
    'Gender': 'Woman'
},{
    'url': 'https://www.ebay.ph/sch/i.html?_from=R40&_trksid=m570.l1313&_nkw=woman+shorts&_sacat=0&LH_TitleDesc=0&_osacat=0&_odkw=woman+shots&LH_PrefLoc=2',
    'main_container':['li', 's-item s-item__pl-on-bottom'],
    
    'fetch_data_item':[
        ['Name', 'div', 's-item__title'],
        ['Link', 'a', 's-item__link'],
        ['Image', 'img', 's-item__image-img'],
        ['Price', 'span', 's-item__price']
    ],
    
    'Store': 'eBay',
    'item_len': Len,
    'Category': 'Shorts',
    'Gender': 'Woman'
},{
    'url': 'https://www.ebay.com/sch/i.html?_from=R40&_trksid=p2334524.m570.l1313&_nkw=skirt+for+woman&_sacat=0&LH_TitleDesc=0&_odkw=skirt+for+woman&_osacat=0',
    'main_container':['li', 's-item s-item__pl-on-bottom'],
    
    'fetch_data_item':[
        ['Name', 'div', 's-item__title'],
        ['Link', 'a', 's-item__link'],
        ['Image', 'img', 's-item__image-img'],
        ['Price', 'span', 's-item__price']
    ],
    
    'Store': 'eBay',
    'item_len': Len,
    'Category': 'Skirt',
    'Gender': 'Woman'
},{
    'url': 'https://www.ebay.ph/sch/i.html?_from=R40&_trksid=m570.l1313&_nkw=woman+belt+&_sacat=0&LH_TitleDesc=0&_odkw=woman+shorts&_osacat=0&LH_PrefLoc=2',
    'main_container':['li', 's-item s-item__pl-on-bottom'],
    
    'fetch_data_item':[
        ['Name', 'div', 's-item__title'],
        ['Link', 'a', 's-item__link'],
        ['Image', 'img', 's-item__image-img'],
        ['Price', 'span', 's-item__price']
    ],
    
    'Store': 'eBay',
    'item_len': Len,
    'Category': 'Belt',
    'Gender': 'Woman'
}]

# %%
import json 

def to_json_form(items_data, filename):
    with open(f'C:/Users/emielou/Desktop/scraping/Queries/{filename}.json', 'w', encoding='latin-1') as f:
        json.dump(items_data, f, indent=8, ensure_ascii=False)
        print('Done...')

# %%
to_json_form(scrape_flipkart, 'flipkart_queries')

# %%
to_json_form(scrape_amazon, 'amazon_queries')

# %%
to_json_form(scrape_eBay, 'eBay_queries')
