# %%
Len=10

# %%
#Creative Style
scrape_amazon = [{
    'url':'https://www.amazon.com/s?k=jacket+for+women&crid=133QU8Y63L5B3&sprefix=jacket+for+women%2Caps%2C358&ref=nb_sb_noss_1',
    'main_container': ['div', "a-section a-spacing-base"],

    'fetch_data_item': [   
        ['Name', 'span', "a-size-base-plus a-color-base a-text-normal"],
        ['Link', 'a', 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'],
        ['Image', 'img', 's-image'],
        ['Price', 'span', 'a-offscreen'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Amazon",
    'item_len': Len, 
    'Category': 'Jacket',
    'Gender' : 'Woman'
},{
    'url':'https://www.amazon.com/s?k=boots+for+women&crid=2XF9KGX1V1YFN&sprefix=boots+for+%2Caps%2C956&ref=nb_sb_ss_ts-doa-p_1_10',
    'main_container': ['div', "a-section a-spacing-base"],

    'fetch_data_item': [   
        ['Name', 'span', "a-size-base-plus a-color-base a-text-normal"],
        ['Link', 'a', 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'],
        ['Image', 'img', 's-image'],
        ['Price', 'span', 'a-offscreen'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Amazon",
    'item_len': Len, 
    'Category': 'Boots',
    'Gender' : 'Woman'
},{
    'url':'https://www.amazon.com/s?k=polo+shirt+for+women&crid=IZ4RQ04BB1RX&sprefix=polo+shirt+for+women%2Caps%2C385&ref=nb_sb_noss_1',
    'main_container': ['div', "a-section a-spacing-base"],

    'fetch_data_item': [   
        ['Name', 'span', "a-size-base-plus a-color-base a-text-normal"],
        ['Link', 'a', 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'],
        ['Image', 'img', 's-image'],
        ['Price', 'span', 'a-offscreen'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Amazon",
    'item_len': Len, 
    'Category': 'Polo shirt',
    'Gender' : 'Woman'
},{
    'url':'https://www.amazon.com/s?k=vest+for+women&crid=3JD7LCJ3606E2&sprefix=vestfor+women%2Caps%2C310&ref=nb_sb_noss_2',
    'main_container': ['div', "a-section a-spacing-base"],

    'fetch_data_item': [   
        ['Name', 'span', "a-size-base-plus a-color-base a-text-normal"],
        ['Link', 'a', 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'],
        ['Image', 'img', 's-image'],
        ['Price', 'span', 'a-offscreen'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Amazon",
    'item_len': Len, 
    'Category': 'Vest',
    'Gender' : 'Woman'
   
},{'url':'https://www.amazon.com/s?k=coats+for+women&crid=34TCCYSF4HNN9&sprefix=coats+for+women%2Caps%2C332&ref=nb_sb_noss_1',
    'main_container': ['div', "a-section a-spacing-base"],

    'fetch_data_item': [   
        ['Name', 'span', "a-size-base-plus a-color-base a-text-normal"],
        ['Link', 'a', 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'],
        ['Image', 'img', 's-image'],
        ['Price', 'span', 'a-offscreen'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Amazon",
    'item_len': Len, 
    'Category': 'Coats',
    'Gender' : 'Woman'
   
},{'url':'https://www.amazon.com/s?k=pants+for+women&crid=84S6V77ICGY6&sprefix=pantsfor+women%2Caps%2C318&ref=nb_sb_noss_2',
    'main_container': ['div', "a-section a-spacing-base"],

    'fetch_data_item': [   
        ['Name', 'span', "a-size-base-plus a-color-base a-text-normal"],
        ['Link', 'a', 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'],
        ['Image', 'img', 's-image'],
        ['Price', 'span', 'a-offscreen'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Amazon",
    'item_len': Len, 
    'Category': 'Pants',
    'Gender' : 'Woman'
#men  
},{
    'url':'https://www.amazon.com/s?k=jackets+for+men&crid=3Y0XT5IGAPTI&sprefix=jackets+for+me%2Caps%2C316&ref=nb_sb_noss_2',
    'main_container': ['div', "a-section a-spacing-base"],

    'fetch_data_item': [   
        ['Name', 'span', "a-size-base-plus a-color-base a-text-normal"],
        ['Link', 'a', 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'],
        ['Image', 'img', 's-image'],
        ['Price', 'span', 'a-offscreen'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Amazon",
    'item_len': Len, 
    'Category': 'Jacket',
    'Gender' : 'Men'
},{
    'url':'https://www.amazon.com/s?k=boots+for+men&crid=MBW9IEIL2C5Q&sprefix=boot+for+men%2Caps%2C382&ref=nb_sb_noss_1',
    'main_container': ['div', "a-section a-spacing-base"],

    'fetch_data_item': [   
        ['Name', 'span', "a-size-base-plus a-color-base a-text-normal"],
        ['Link', 'a', 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'],
        ['Image', 'img', 's-image'],
        ['Price', 'span', 'a-offscreen'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Amazon",
    'item_len': Len, 
    'Category': 'Boots',
    'Gender' : 'Men'
},{
    'url':'https://www.amazon.com/s?k=polo+shirt+for+men&crid=1OBOMIC6VUC3B&sprefix=polo+shirt+for+men%2Caps%2C322&ref=nb_sb_noss_1',
    'main_container': ['div', "a-section a-spacing-base"],

    'fetch_data_item': [   
        ['Name', 'span', "a-size-base-plus a-color-base a-text-normal"],
        ['Link', 'a', 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'],
        ['Image', 'img', 's-image'],
        ['Price', 'span', 'a-offscreen'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Amazon",
    'item_len': Len, 
    'Category': 'Polo shirt',
    'Gender' : 'Men'
},{
    'url':'https://www.amazon.com/s?k=vest+for+men&crid=2OEFKMAC2MS48&sprefix=vest+for+men%2Caps%2C325&ref=nb_sb_noss_1',
    'main_container': ['div', "a-section a-spacing-base"],

    'fetch_data_item': [   
        ['Name', 'span', "a-size-base-plus a-color-base a-text-normal"],
        ['Link', 'a', 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'],
        ['Image', 'img', 's-image'],
        ['Price', 'span', 'a-offscreen'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Amazon",
    'item_len': Len, 
    'Category': 'Vest',
    'Gender' : 'Men'
   
},{'url':'https://www.amazon.com/s?k=coat+for+men&crid=KT9NC1KG5MHR&sprefix=coat+for+men%2Caps%2C321&ref=nb_sb_noss_1',
    'main_container': ['div', "a-section a-spacing-base"],

    'fetch_data_item': [   
        ['Name', 'span', "a-size-base-plus a-color-base a-text-normal"],
        ['Link', 'a', 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'],
        ['Image', 'img', 's-image'],
        ['Price', 'span', 'a-offscreen'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Amazon",
    'item_len': Len, 
    'Category': 'Coats',
    'Gender' : 'Men'
   
},{'url':'https://www.amazon.com/s?k=pants+for+men&crid=2SPIJ9SR3V8DD&sprefix=pant+for+men%2Caps%2C328&ref=nb_sb_noss_1',
    'main_container': ['div', "a-section a-spacing-base"],

    'fetch_data_item': [   
        ['Name', 'span', "a-size-base-plus a-color-base a-text-normal"],
        ['Link', 'a', 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'],
        ['Image', 'img', 's-image'],
        ['Price', 'span', 'a-offscreen'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Amazon",
    'item_len': Len, 
    'Category': 'Pants',
    'Gender' : 'Men'
}]

# %%
#Modern Style
scrape_amazon = [{
    'url':'https://www.amazon.com/s?k=bags+for+woman&crid=2G74R3KOUZ1S8&sprefix=bags+for+woma%2Caps%2C305&ref=nb_sb_noss_2',
    'main_container': ['div', "a-section a-spacing-base"],

    'fetch_data_item': [   
        ['Name', 'span', "a-size-base-plus a-color-base a-text-normal"],
        ['Link', 'a', 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'],
        ['Image', 'img', 's-image'],
        ['Price', 'span', 'a-offscreen'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Amazon",
    'item_len': Len, 
    'Category': 'Bags',
    'Gender' : 'Woman'
},{
    'url':'https://www.amazon.com/s?k=casual+t-shirt+for+woman&crid=3J9KC32E5RGDP&sprefix=casual+t-shirtfor+woman%2Caps%2C329&ref=nb_sb_noss',
    'main_container': ['div', "a-section a-spacing-base"],

    'fetch_data_item': [   
        ['Name', 'span', "a-size-base-plus a-color-base a-text-normal"],
        ['Link', 'a', 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'],
        ['Image', 'img', 's-image'],
        ['Price', 'span', 'a-offscreen'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Amazon",
    'item_len': Len, 
    'Category': 'Casual t-shirt',
    'Gender' : 'Woman'
},{
    'url':'https://www.amazon.com/s?k=printed+t-shirt+for+woman&crid=P77VQ1GFSWRK&sprefix=printedt-shirt+for+woman%2Caps%2C309&ref=nb_sb_noss',
    'main_container': ['div', "a-section a-spacing-base"],

    'fetch_data_item': [   
        ['Name', 'span', "a-size-base-plus a-color-base a-text-normal"],
        ['Link', 'a', 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'],
        ['Image', 'img', 's-image'],
        ['Price', 'span', 'a-offscreen'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Amazon",
    'item_len': Len, 
    'Category': 'Printed t-shirt',
    'Gender' : 'Woman'
},{
    'url':'https://www.amazon.com/s?k=summer+cloth+for+woman&crid=34WGXK3QMBRKP&sprefix=summer+cloth+for+woman%2Caps%2C322&ref=nb_sb_noss_2',
    'main_container': ['div', "a-section a-spacing-base"],

    'fetch_data_item': [   
        ['Name', 'span', "a-size-base-plus a-color-base a-text-normal"],
        ['Link', 'a', 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'],
        ['Image', 'img', 's-image'],
        ['Price', 'span', 'a-offscreen'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Amazon",
    'item_len': Len, 
    'Category': 'Summer Cloth',
    'Gender' : 'Woman'
   
},{'url':'https://www.amazon.com/s?k=swimwear+for+woman&crid=3EF435IKUJ5EH&sprefix=swimwear+for+woman%2Caps%2C326&ref=nb_sb_noss_2',
    'main_container': ['div', "a-section a-spacing-base"],

    'fetch_data_item': [   
        ['Name', 'span', "a-size-base-plus a-color-base a-text-normal"],
        ['Link', 'a', 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'],
        ['Image', 'img', 's-image'],
        ['Price', 'span', 'a-offscreen'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Amazon",
    'item_len': Len, 
    'Category': 'Swimwear',
    'Gender' : 'Woman'
   
},{'url':'https://www.amazon.com/s?k=night+dress+for+woman&crid=M3K9R4S8H5AH&sprefix=night+dressfor+woman%2Caps%2C317&ref=nb_sb_noss_2',
    'main_container': ['div', "a-section a-spacing-base"],

    'fetch_data_item': [   
        ['Name', 'span', "a-size-base-plus a-color-base a-text-normal"],
        ['Link', 'a', 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'],
        ['Image', 'img', 's-image'],
        ['Price', 'span', 'a-offscreen'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Amazon",
    'item_len': Len, 
    'Category': 'Nightdress',
    'Gender' : 'Woman'
#men  
},{
    'url':'https://www.amazon.com/s?k=bags+for+men&crid=2VBUFBU5UQP8B&sprefix=bags+for+men%2Caps%2C328&ref=nb_sb_noss_1',
    'main_container': ['div', "a-section a-spacing-base"],

    'fetch_data_item': [   
        ['Name', 'span', "a-size-base-plus a-color-base a-text-normal"],
        ['Link', 'a', 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'],
        ['Image', 'img', 's-image'],
        ['Price', 'span', 'a-offscreen'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Amazon",
    'item_len': Len, 
    'Category': 'Bags',
    'Gender' : 'Men'
},{
    'url':'https://www.amazon.com/s?k=casual+t-shirt+for+men&crid=21HEPZ7CA5B1I&sprefix=casual+t-shirt+for+men%2Caps%2C337&ref=nb_sb_noss_1',
    'main_container': ['div', "a-section a-spacing-base"],

    'fetch_data_item': [   
        ['Name', 'span', "a-size-base-plus a-color-base a-text-normal"],
        ['Link', 'a', 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'],
        ['Image', 'img', 's-image'],
        ['Price', 'span', 'a-offscreen'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Amazon",
    'item_len': Len, 
    'Category': 'Casual t-shirt',
    'Gender' : 'Men'
},{
    'url':'https://www.amazon.com/s?k=printed+t-shirt+for+men&crid=2H7V0SXS06PIN&sprefix=printedt-shirt+for+men%2Caps%2C367&ref=nb_sb_noss',
    'main_container': ['div', "a-section a-spacing-base"],

    'fetch_data_item': [   
        ['Name', 'span', "a-size-base-plus a-color-base a-text-normal"],
        ['Link', 'a', 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'],
        ['Image', 'img', 's-image'],
        ['Price', 'span', 'a-offscreen'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Amazon",
    'item_len': Len, 
    'Category': 'Printed t-shirt',
    'Gender' : 'Men'
},{
    'url':'https://www.amazon.com/s?k=summer+cloth+for+men&crid=16R88T1GIRD46&sprefix=summer+cloth+for+men%2Caps%2C304&ref=nb_sb_noss_1',
    'main_container': ['div', "a-section a-spacing-base"],

    'fetch_data_item': [   
        ['Name', 'span', "a-size-base-plus a-color-base a-text-normal"],
        ['Link', 'a', 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'],
        ['Image', 'img', 's-image'],
        ['Price', 'span', 'a-offscreen'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Amazon",
    'item_len': Len, 
    'Category': 'Summer Cloth',
    'Gender' : 'Men'
   
},{'url':'https://www.amazon.com/s?k=swimwear+for+men&crid=335E7UBQTTJ1Q&sprefix=swimwear+for+men%2Caps%2C314&ref=nb_sb_noss_1',
    'main_container': ['div', "a-section a-spacing-base"],

    'fetch_data_item': [   
        ['Name', 'span', "a-size-base-plus a-color-base a-text-normal"],
        ['Link', 'a', 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'],
        ['Image', 'img', 's-image'],
        ['Price', 'span', 'a-offscreen'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Amazon",
    'item_len': Len, 
    'Category': 'Swimwear',
    'Gender' : 'Men'
}]

# %%
#Stylish
scrape_amazon = [{
    'url':'https://www.amazon.com/s?k=dress+for+women&crid=3I02JL9C5Q0I1&sprefix=dress+for+women%2Caps%2C332&ref=nb_sb_noss_1',
    'main_container': ['div', "a-section a-spacing-base"],

    'fetch_data_item': [   
        ['Name', 'span', "a-size-base-plus a-color-base a-text-normal"],
        ['Link', 'a', 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'],
        ['Image', 'img', 's-image'],
        ['Price', 'span', 'a-offscreen'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Amazon",
    'item_len': Len, 
    'Category': 'Dress',
    'Gender' : 'Woman'
},{
    'url':'https://www.amazon.com/s?k=jeans+for+women&crid=377HIBFKKBE8L&sprefix=jeansfor+women%2Caps%2C337&ref=nb_sb_noss_2',
    'main_container': ['div', "a-section a-spacing-base"],

    'fetch_data_item': [   
        ['Name', 'span', "a-size-base-plus a-color-base a-text-normal"],
        ['Link', 'a', 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'],
        ['Image', 'img', 's-image'],
        ['Price', 'span', 'a-offscreen'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Amazon",
    'item_len': Len, 
    'Category': 'Jeans',
    'Gender' : 'Woman'
},{
    'url':'https://www.amazon.com/s?k=shirt+for+women&crid=2QE9ZBN9DPN4P&sprefix=shirtfor+women%2Caps%2C327&ref=nb_sb_noss_2',
    'main_container': ['div', "a-section a-spacing-base"],

    'fetch_data_item': [   
        ['Name', 'span', "a-size-base-plus a-color-base a-text-normal"],
        ['Link', 'a', 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'],
        ['Image', 'img', 's-image'],
        ['Price', 'span', 'a-offscreen'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Amazon",
    'item_len': Len, 
    'Category': 'Shirt',
    'Gender' : 'Woman'
},{
    'url':'https://www.amazon.com/s?k=short+for+women&crid=2MHVC7IUOJUYN&sprefix=short+for+women%2Caps%2C355&ref=nb_sb_noss_1',
    'main_container': ['div', "a-section a-spacing-base"],

    'fetch_data_item': [   
        ['Name', 'span', "a-size-base-plus a-color-base a-text-normal"],
        ['Link', 'a', 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'],
        ['Image', 'img', 's-image'],
        ['Price', 'span', 'a-offscreen'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Amazon",
    'item_len': Len, 
    'Category': 'Shorts',
    'Gender' : 'Woman'
   
},{'url':'https://www.amazon.com/s?k=party+dress+for+women&crid=KX59MXK6OI54&sprefix=party+dre+for+women%2Caps%2C353&ref=nb_sb_noss_2',
    'main_container': ['div', "a-section a-spacing-base"],

    'fetch_data_item': [   
        ['Name', 'span', "a-size-base-plus a-color-base a-text-normal"],
        ['Link', 'a', 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'],
        ['Image', 'img', 's-image'],
        ['Price', 'span', 'a-offscreen'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Amazon",
    'item_len': Len, 
    'Category': 'Party dress',
    'Gender' : 'Woman'
   
},{'url':'https://www.amazon.com/s?k=winter+coats+for+women&crid=31TUMBEREGJG6&sprefix=winter+coatsfor+women%2Caps%2C312&ref=nb_sb_noss_2',
    'main_container': ['div', "a-section a-spacing-base"],

    'fetch_data_item': [   
        ['Name', 'span', "a-size-base-plus a-color-base a-text-normal"],
        ['Link', 'a', 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'],
        ['Image', 'img', 's-image'],
        ['Price', 'span', 'a-offscreen'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Amazon",
    'item_len': Len, 
    'Category': 'Winter Coats',
    'Gender' : 'Woman'
 
},{'url':'https://www.amazon.com/s?k=trouser+for+women&crid=2GYSXAM5Q33JC&sprefix=trouser+for+women%2Caps%2C336&ref=nb_sb_noss_1',
    'main_container': ['div', "a-section a-spacing-base"],

    'fetch_data_item': [   
        ['Name', 'span', "a-size-base-plus a-color-base a-text-normal"],
        ['Link', 'a', 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'],
        ['Image', 'img', 's-image'],
        ['Price', 'span', 'a-offscreen'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Amazon",
    'item_len': Len, 
    'Category': 'Trouser',
    'Gender' : 'Woman'
   
},{'url':'https://www.amazon.com/s?k=skirt+for+women&crid=3E4AH7NPM4UE2&sprefix=skirt+for+women%2Caps%2C336&ref=nb_sb_noss_1',
    'main_container': ['div', "a-section a-spacing-base"],

    'fetch_data_item': [   
        ['Name', 'span', "a-size-base-plus a-color-base a-text-normal"],
        ['Link', 'a', 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'],
        ['Image', 'img', 's-image'],
        ['Price', 'span', 'a-offscreen'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Amazon",
    'item_len': Len, 
    'Category': 'Skirt',
    'Gender' : 'Woman'
#men   
},{
    'url':'https://www.amazon.com/s?k=jeans+for+men&crid=27IQFVR4AKCSR&sprefix=jeans+for+me%2Caps%2C329&ref=nb_sb_noss_2',
    'main_container': ['div', "a-section a-spacing-base"],

    'fetch_data_item': [   
        ['Name', 'span', "a-size-base-plus a-color-base a-text-normal"],
        ['Link', 'a', 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'],
        ['Image', 'img', 's-image'],
        ['Price', 'span', 'a-offscreen'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Amazon",
    'item_len': Len, 
    'Category': 'Jeans',
    'Gender' : 'Men'
},{
    'url':'https://www.amazon.com/s?k=shirt+for+men&crid=1HVUSYPK9UXTW&sprefix=shirt+for+men%2Caps%2C329&ref=nb_sb_noss_1',
    'main_container': ['div', "a-section a-spacing-base"],

    'fetch_data_item': [   
        ['Name', 'span', "a-size-base-plus a-color-base a-text-normal"],
        ['Link', 'a', 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'],
        ['Image', 'img', 's-image'],
        ['Price', 'span', 'a-offscreen'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Amazon",
    'item_len': Len, 
    'Category': 'Shirt',
    'Gender' : 'Men'
},{
    'url':'https://www.amazon.com/s?k=short+for+men&crid=124URTLMWZR3Q&sprefix=short+for+men%2Caps%2C312&ref=nb_sb_noss_2',
    'main_container': ['div', "a-section a-spacing-base"],

    'fetch_data_item': [   
        ['Name', 'span', "a-size-base-plus a-color-base a-text-normal"],
        ['Link', 'a', 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'],
        ['Image', 'img', 's-image'],
        ['Price', 'span', 'a-offscreen'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Amazon",
    'item_len': Len, 
    'Category': 'Shorts',
    'Gender' : 'Men'
   
},{'url':'https://www.amazon.com/s?k=party+wear+for+men&crid=1XKSE279ATKGT&sprefix=party+wear+for+men%2Caps%2C321&ref=nb_sb_noss_1',
    'main_container': ['div', "a-section a-spacing-base"],

    'fetch_data_item': [   
        ['Name', 'span', "a-size-base-plus a-color-base a-text-normal"],
        ['Link', 'a', 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'],
        ['Image', 'img', 's-image'],
        ['Price', 'span', 'a-offscreen'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Amazon",
    'item_len': Len, 
    'Category': 'Party wear',
    'Gender' : 'Men'
   
},{'url':'https://www.amazon.com/s?k=winter+coats+for+men&crid=1RPOOPIIO27OA&sprefix=winter+coatsfor+men%2Caps%2C314&ref=nb_sb_noss_2',
    'main_container': ['div', "a-section a-spacing-base"],

    'fetch_data_item': [   
        ['Name', 'span', "a-size-base-plus a-color-base a-text-normal"],
        ['Link', 'a', 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'],
        ['Image', 'img', 's-image'],
        ['Price', 'span', 'a-offscreen'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Amazon",
    'item_len': Len, 
    'Category': 'Winter Coats',
    'Gender' : 'Men'
 
},{'url':'https://www.amazon.com/s?k=trouser+for+men&crid=3SVW5160BU6BM&sprefix=trouser+for+men%2Caps%2C334&ref=nb_sb_noss_1',
    'main_container': ['div', "a-section a-spacing-base"],

    'fetch_data_item': [   
        ['Name', 'span', "a-size-base-plus a-color-base a-text-normal"],
        ['Link', 'a', 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'],
        ['Image', 'img', 's-image'],
        ['Price', 'span', 'a-offscreen'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Amazon",
    'item_len': Len, 
    'Category': 'Trouser',
    'Gender' : 'Men'
   
}]

# %%
#Sport Style
scrape_amazon = [{
    'url':'https://www.amazon.com/s?k=sport+bra+for+woman&ref=nb_sb_noss',
    'main_container': ['div', "a-section a-spacing-base"],

    'fetch_data_item': [   
        ['Name', 'span', "a-size-base-plus a-color-base a-text-normal"],
        ['Link', 'a', 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'],
        ['Image', 'img', 's-image'],
        ['Price', 'span', 'a-offscreen'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Amazon",
    'item_len': Len, 
    'Category': 'Sports bra',
    'Gender' : 'Woman'
},{
    'url':'https://www.amazon.com/s?k=sport+shoes+for+woman&crid=39CBU1QXNDINL&sprefix=sport+shoe+for+woman%2Caps%2C383&ref=nb_sb_noss_2',
    'main_container': ['div', "a-section a-spacing-base"],

    'fetch_data_item': [   
        ['Name', 'span', "a-size-base-plus a-color-base a-text-normal"],
        ['Link', 'a', 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'],
        ['Image', 'img', 's-image'],
        ['Price', 'span', 'a-offscreen'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Amazon",
    'item_len': Len, 
    'Category': 'Sports shoes',
    'Gender' : 'Woman'
},{
    'url':'https://www.amazon.com/s?k=sport+bag+for+woman&crid=3M8W3O11N8AIR&sprefix=sport+bag+for+women%2Caps%2C335&ref=nb_sb_noss_1',
    'main_container': ['div', "a-section a-spacing-base"],

    'fetch_data_item': [   
        ['Name', 'span', "a-size-base-plus a-color-base a-text-normal"],
        ['Link', 'a', 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'],
        ['Image', 'img', 's-image'],
        ['Price', 'span', 'a-offscreen'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Amazon",
    'item_len': Len, 
    'Category': 'Sports bag',
    'Gender' : 'Woman'
},{
    'url':'https://www.amazon.com/s?k=activewear+for+woman&crid=35UJGPB8H6820&sprefix=activewearfor+woman%2Caps%2C318&ref=nb_sb_noss_2',
    'main_container': ['div', "a-section a-spacing-base"],

    'fetch_data_item': [   
        ['Name', 'span', "a-size-base-plus a-color-base a-text-normal"],
        ['Link', 'a', 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'],
        ['Image', 'img', 's-image'],
        ['Price', 'span', 'a-offscreen'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Amazon",
    'item_len': Len, 
    'Category': 'Activewear',
    'Gender' : 'Woman'
   
},{'url':'https://www.amazon.com/s?k=trunks+for+woman&crid=U4R0AZHYMR32&sprefix=trunks+for+woman%2Caps%2C334&ref=nb_sb_noss_1',
    'main_container': ['div', "a-section a-spacing-base"],

    'fetch_data_item': [   
        ['Name', 'span', "a-size-base-plus a-color-base a-text-normal"],
        ['Link', 'a', 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'],
        ['Image', 'img', 's-image'],
        ['Price', 'span', 'a-offscreen'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Amazon",
    'item_len': Len, 
    'Category': 'Trunks',
    'Gender' : 'Woman'
   
},{'url':'https://www.amazon.com/s?k=sport+headband+for+woman&crid=VATDZAHG41VZ&sprefix=sport+headban+for+woman%2Caps%2C331&ref=nb_sb_noss',
    'main_container': ['div', "a-section a-spacing-base"],

    'fetch_data_item': [   
        ['Name', 'span', "a-size-base-plus a-color-base a-text-normal"],
        ['Link', 'a', 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'],
        ['Image', 'img', 's-image'],
        ['Price', 'span', 'a-offscreen'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Amazon",
    'item_len': Len, 
    'Category': 'Sports headband',
    'Gender' : 'Woman'
 
},{'url':'https://www.amazon.com/s?k=jugging+for+woman&crid=1AA0AL2JQC7HW&sprefix=jugging+for+woman%2Caps%2C332&ref=nb_sb_noss_2',
    'main_container': ['div', "a-section a-spacing-base"],

    'fetch_data_item': [   
        ['Name', 'span', "a-size-base-plus a-color-base a-text-normal"],
        ['Link', 'a', 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'],
        ['Image', 'img', 's-image'],
        ['Price', 'span', 'a-offscreen'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Amazon",
    'item_len': Len, 
    'Category': 'Jogging Pants',
    'Gender' : 'Woman'
#men  
},{
    'url':'https://www.amazon.com/s?k=sport+shoes+for+men&crid=FSCB22CE4D7E&sprefix=sport+shoes+for+me%2Caps%2C366&ref=nb_sb_noss_2',
    'main_container': ['div', "a-section a-spacing-base"],

    'fetch_data_item': [   
        ['Name', 'span', "a-size-base-plus a-color-base a-text-normal"],
        ['Link', 'a', 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'],
        ['Image', 'img', 's-image'],
        ['Price', 'span', 'a-offscreen'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Amazon",
    'item_len': Len, 
    'Category': 'Sports shoes',
    'Gender' : 'Men'
},{
    'url':'https://www.amazon.com/s?k=sport+bags+for+men&crid=3665ZSIEV50GK&sprefix=sport+bag+for+men%2Caps%2C328&ref=nb_sb_noss_1',
    'main_container': ['div', "a-section a-spacing-base"],

    'fetch_data_item': [   
        ['Name', 'span', "a-size-base-plus a-color-base a-text-normal"],
        ['Link', 'a', 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'],
        ['Image', 'img', 's-image'],
        ['Price', 'span', 'a-offscreen'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Amazon",
    'item_len': Len, 
    'Category': 'Sports bag',
    'Gender' : 'Men'
},{
    'url':'2https://www.amazon.com/s?k=active+wear+for+men&crid=GQIMEFHCSRG&sprefix=active+wear+for+men%2Caps%2C330&ref=nb_sb_noss_2',
    'main_container': ['div', "a-section a-spacing-base"],

    'fetch_data_item': [   
        ['Name', 'span', "a-size-base-plus a-color-base a-text-normal"],
        ['Link', 'a', 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'],
        ['Image', 'img', 's-image'],
        ['Price', 'span', 'a-offscreen'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Amazon",
    'item_len': Len, 
    'Category': 'Activewear',
    'Gender' : 'Men'
   
},{'url':'https://www.amazon.com/s?k=trunks+for+men&crid=2OYFFZRL6SJX3&sprefix=trunks+for+men%2Caps%2C328&ref=nb_sb_noss_1',
    'main_container': ['div', "a-section a-spacing-base"],

    'fetch_data_item': [   
        ['Name', 'span', "a-size-base-plus a-color-base a-text-normal"],
        ['Link', 'a', 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'],
        ['Image', 'img', 's-image'],
        ['Price', 'span', 'a-offscreen'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Amazon",
    'item_len': Len, 
    'Category': 'Trunks',
    'Gender' : 'Men'
   
},{'url':'https://www.amazon.com/s?k=sport+headband+for+men&crid=1JJMLVSF4ZEJM&sprefix=sport+headbandfor+men%2Caps%2C316&ref=nb_sb_noss_2',
    'main_container': ['div', "a-section a-spacing-base"],

    'fetch_data_item': [   
        ['Name', 'span', "a-size-base-plus a-color-base a-text-normal"],
        ['Link', 'a', 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'],
        ['Image', 'img', 's-image'],
        ['Price', 'span', 'a-offscreen'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Amazon",
    'item_len': Len, 
    'Category': 'Sports headband',
    'Gender' : 'Men'
 
},{'url':'https://www.amazon.com/s?k=jogging+pants+for+men&crid=2GDZ13EMJ9CCI&sprefix=jogging+pants+for+men%2Caps%2C326&ref=nb_sb_noss_1',
    'main_container': ['div', "a-section a-spacing-base"],

    'fetch_data_item': [   
        ['Name', 'span', "a-size-base-plus a-color-base a-text-normal"],
        ['Link', 'a', 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'],
        ['Image', 'img', 's-image'],
        ['Price', 'span', 'a-offscreen'],
        ['Ratings','div','_3LWZlK _3uSWvT']
    ],
    
    'Store': "Amazon",
    'item_len': Len, 
    'Category': 'Jogging Pants',
    'Gender' : 'men'
   
}]
